# %%
import os

# %%
print (dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_ex
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\jaced\Desktop\N6806\Week3\Week3

# %%
os.chdir('/Users/jaced/Desktop')

# %%
print (os.getcwd())
# Out:
# C:\Users\jaced\Desktop

# %%
print (os.listdir())
# Out:
# ['Application', 'CCN Content Advisor', 'Cisco Webex Meetings.lnk', 'CJON Manuscript 12.2020', 'desktop.ini', 'HAPPI Initiative', 'Home', 'Immunology. Peronditis and RA.pdf', 'JaceJ.txt', 'Lease.pdf', 'Lectures', 'Licensing. Cert. Credentialing', 'myProject', 'MyProject2', 'MyProject3', 'N6806', 'N7472 Fall 2021 Case 1-1 without answers.docx', 'ONCC', 'PhD Coursework', 'Pulmonary and Critical Care Medicine Guide', 'Pulmonary Immunology', 'Risk Stratification in Respiratory Failure', 'SM', 'SO', 'Temp License.pdf', 'Towing and auto info.docx', 'Video Lectures', 'Visual Studio Code.lnk', 'Work Credentialing', '~$docrine Notes.docx', '~$N Reviewer Comments_JJOHNNY.docx', '~$OHNNY_CV_02.2021.docx', '~$troduction and Inflammasome Overview.docx', '~WRL0003.tmp', '~WRL0005.tmp', '~WRL2127.tmp', '~WRL2526.tmp']

# %%
os.mkdir('OS-Demo-2')

# %%
os.rmdir('OS-Demo-2')

# %%
print (os.stat ('~WRL0003.tmp'))
# Out:
# os.stat_result(st_mode=33206, st_ino=8162774324711643, st_dev=2967882095, st_nlink=1, st_uid=0, st_gid=0, st_size=300018, st_atime=1630444918, st_mtime=1610419618, st_ctime=1610418968)

# %%
mod_time = print (os.stat('~WRL0003.tmp').st_mtime)
# Out:
# 1610419618.9649584

# %%
print (os.listdir())
# Out:
# ['Application', 'CCN Content Advisor', 'Cisco Webex Meetings.lnk', 'CJON Manuscript 12.2020', 'desktop.ini', 'HAPPI Initiative', 'Home', 'Immunology. Peronditis and RA.pdf', 'JaceJ.txt', 'Lease.pdf', 'Lectures', 'Licensing. Cert. Credentialing', 'myProject', 'MyProject2', 'MyProject3', 'N6806', 'N7472 Fall 2021 Case 1-1 without answers.docx', 'ONCC', 'PhD Coursework', 'Pulmonary and Critical Care Medicine Guide', 'Pulmonary Immunology', 'Risk Stratification in Respiratory Failure', 'SM', 'SO', 'Temp License.pdf', 'Towing and auto info.docx', 'Video Lectures', 'Visual Studio Code.lnk', 'Work Credentialing', '~$docrine Notes.docx', '~$N Reviewer Comments_JJOHNNY.docx', '~$OHNNY_CV_02.2021.docx', '~$troduction and Inflammasome Overview.docx', '~WRL0003.tmp', '~WRL0005.tmp', '~WRL2127.tmp', '~WRL2526.tmp']

# %%
from datetime import datetime

# %%
os.chdir('/Users/jaced/Desktop')

# %%
for dirpath, dirnames, filenames in os.walk('/Users/jaced/Desktop'):
    print ('Current Path:', dirpath)
    print ('Directories:', dirnames)
    print ('Files:', filenames)
    print ()
# Out:
# Current Path: /Users/jaced/Desktop
# Directories: ['Application', 'CCN Content Advisor', 'CJON Manuscript 12.2020', 'HAPPI Initiative', 'Home', 'Lectures', 'Licensing. Cert. Credentialing', 'myProject', 'MyProject2', 'MyProject3', 'N6806', 'ONCC', 'PhD Coursework', 'Pulmonary and Critical Care Medicine Guide', 'Pulmonary Immunology', 'Risk Stratification in Respiratory Failure', 'SM', 'SO', 'Video Lectures', 'Work Credentialing']
# Files: ['Cisco Webex Meetings.lnk', 'desktop.ini', 'Immunology. Peronditis and RA.pdf', 'JaceJ.txt', 'Lease.pdf', 'N7472 Fall 2021 Case 1-1 without answers.docx', 'Temp License.pdf', 'Towing and auto info.docx', 'Visual Studio Code.lnk', '~$docrine Notes.docx', '~$N Reviewer Comments_JJOHNNY.docx', '~$OHNNY_CV_02.2021.docx', '~$troduction and Inflammasome Overview.docx', '~WRL0003.tmp', '~WRL0005.tmp', '~WRL2127.tmp', '~WRL2526.tmp']
#
# Current Path: /Users/jaced/Desktop\Application
# ...

# %%
print (os.environ.get('HOME'))
# Out:
# None

# %%
print(os.path.basename('/tmp/test.txt'))
# Out:
# test.txt

# %%
print (os.path.split('tmp/test.txt'))
# Out:
# ('tmp', 'test.txt')

# %%
print (dir(os.path))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_abspath_fallback', '_get_bothseps', '_getfinalpathname', '_getfinalpathname_nonstrict', '_getfullpathname', '_getvolumepathname', '_nt_readlink', '_readlink_deep', 'abspath', 'altsep', 'basename', 'commonpath', 'commonprefix', 'curdir', 'defpath', 'devnull', 'dirname', 'exists', 'expanduser', 'expandvars', 'extsep', 'genericpath', 'getatime', 'getctime', 'getmtime', 'getsize', 'isabs', 'isdir', 'isfile', 'islink', 'ismount', 'join', 'lexists', 'normcase', 'normpath', 'os', 'pardir', 'pathsep', 'realpath', 'relpath', 'samefile', 'sameopenfile', 'samestat', 'sep', 'split', 'splitdrive', 'splitext', 'stat', 'supports_unicode_filenames', 'sys']

# %%
print(os.path.isdir('HOME'))
# Out:
# True

# %% [markdown]
# According to this source, you can use 'markdown' to enter comments. https://stackoverflow.com/questions/48869529/inserting-comments-into-jupyter-notebook

# %% [markdown]
# OS Module tutorial URL: https://youtu.be/tJxcKyFMTGo
